# %% [markdown]
# # 🛒E-Commerce Profit Analysis
#
# Exploratory analysis of e-commerce sales, profit, and margin patterns.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

plt.style.use('ggplot')

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv("../data/ecommerce_sales_data.csv")
df.head()
# Out:
#    Order Date Product Name                              Products     Category  \
# 0  12/31/2024      Printer                HP LaserJet Pro M404dn       Office
# 1  11/27/2022        Mouse  Logitech MX Master 3S Wireless Mouse  Accessories
# 2  05/11/2022       Tablet            Apple iPad 10th Generation  Electronics
# 3   3/16/2024        Mouse  Logitech MX Master 3S Wireless Mouse  Accessories
# 4  09/10/2022        Mouse  Logitech MX Master 3S Wireless Mouse  Accessories
#
#        Product_Category Region  Quantity    Sales Profit
# 0  Computer Accessories  North         4  $3,640   $349
# 1  Computer Accessories   East         7  $1,197   $107
# 2      Laptops & Mobile  South         5  $5,865   $503
# 3  Computer Accessories  South         2    $786   $203
# 4  Computer Accessories   West         1    $509   $103

# %% [markdown]
# ## 3. Basic Inspection

# %%
display(df.tail())
print('Shape:', df.shape)
print(df.columns.tolist())
print(df.dtypes)
print('Missing values:\n', df.isna().sum())
print('Duplicate rows:', df.duplicated().sum())
display(df.describe(include='all').T)
# Out:
#       Order Date Product Name                             Products  \
# 3495   2/15/2023      Monitor  Dell UltraSharp U2723QE 27' Monitor
# 3496   9/18/2022      Monitor  Dell UltraSharp U2723QE 27' Monitor
# 3497  04/12/2022       Laptop     Lenovo ThinkPad X1 Carbon Gen 11
# 3498   1/18/2022      Printer               HP LaserJet Pro M404dn
# 3499  11/01/2024   Smartwatch                 Apple Watch Series 9
#
#          Category      Product_Category Region  Quantity     Sales   Profit
# 3495  Accessories  Computer Accessories  North         4   $4,064     $771
# 3496  Accessories  Computer Accessories   East         1   $1,117     $120
# 3497  Electronics      Laptops & Mobile  South         4     $260      $66
# 3498       Office  Computer Accessories  South         3     $222      $50
# 3499  Electronics  Consumer Electronics   East         9  $10,530   $1,777
# Shape: (3500, 9)
# ['Order Date', 'Product Name', 'Products', 'Category', 'Product_Category', 'Region', 'Quantity', 'Sales', 'Profit']
# Order Date          object
# Product Name        object
# Products            object
# Category            object
# Product_Category    object
# Region              object
# Quantity             int64
# Sales               object
# Profit              object
# dtype: object
# Missing values:
#  Order Date          0
# Product Name        0
# Products            0
# Category            0
# Product_Category    0
# Region              0
# Quantity            0
# Sales               0
# Profit              0
# dtype: int64
# Duplicate rows: 0
#                    count unique                                  top  freq  \
# Order Date          3500   1051                           08/12/2023    11
# Product Name        3500     10                              Monitor   364
# Products            3500     10  Dell UltraSharp U2723QE 27' Monitor   364
# Category            3500      3                          Electronics  1742
# Product_Category    3500      3                 Computer Accessories  1419
# Region              3500      4                                 West   898
# Quantity          3500.0    NaN                                  NaN   NaN
# Sales               3500   2377                                $384      6
# Profit              3500   1277                                 $94     15
#
#                       mean       std  min  25%  50%  75%  max
# Order Date             NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Product Name           NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Products               NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Category               NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Product_Category       NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Region                 NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Quantity          4.931714  2.575895  1.0  3.0  5.0  7.0  9.0
# Sales                  NaN       NaN  NaN  NaN  NaN  NaN  NaN
# Profit                 NaN       NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ## 4. Cleaning

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
for col in ['Sales', 'Profit']:
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(r'[\$,]', '', regex=True).str.strip(), errors='coerce')
df['Profit Margin'] = df['Profit'] / df['Sales']
df['Year'] = df['Order Date'].dt.year

clean_df = df.drop_duplicates().copy()

# %% [markdown]
# ## 5. Summary Statistics

# %%
clean_df[['Sales','Profit','Quantity','Profit Margin']].describe().T
# Out:
#                 count         mean          std    min          25%  \
# Sales          3500.0  3047.966000  2440.213237  51.00  1049.500000
# Profit         3500.0   527.044286   504.139890   7.00   158.750000
# Quantity       3500.0     4.931714     2.575895   1.00     3.000000
# Profit Margin  3500.0     0.173686     0.071015   0.05     0.113666
#
#                        50%          75%           max
# Sales          2350.500000  4537.000000  10782.000000
# Profit          361.000000   729.250000   2947.000000
# Quantity          5.000000     7.000000      9.000000
# Profit Margin     0.172203     0.233539      0.299891

# %% [markdown]
# ## 6. Correlation Heatmap

# %%
corr = clean_df[['Sales','Profit','Quantity','Profit Margin']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## 7. Yearly Sales and Profit Trend

# %%
yearly = clean_df.groupby('Year')[['Sales','Profit']].sum()
plt.figure(figsize=(8,5))
plt.plot(yearly.index.astype(str), yearly['Sales'], marker='o')
plt.plot(yearly.index.astype(str), yearly['Profit'], marker='o')
plt.title('Yearly Sales and Profit Trend')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.legend(['Sales','Profit'])
plt.show()

# %% [markdown]
# ## 8. Profit Margin by Category

# %%
category = clean_df.groupby('Category')[['Sales','Profit']].sum()
category['Profit Margin'] = category['Profit'] / category['Sales']
category = category.sort_values('Profit Margin')
plt.figure(figsize=(7,5))
plt.bar(category.index, category['Profit Margin'])
plt.title('Profit Margin by Category')
plt.xlabel('Category')
plt.ylabel('Profit Margin')
plt.show()

# %% [markdown]
# ## 9. Profit Margin by Region

# %%
region = clean_df.groupby('Region')[['Sales','Profit']].sum()
region['Profit Margin'] = region['Profit'] / region['Sales']
region = region.sort_values('Profit Margin')
plt.figure(figsize=(7,5))
plt.bar(region.index, region['Profit Margin'])
plt.title('Profit Margin by Region')
plt.xlabel('Region')
plt.ylabel('Profit Margin')
plt.show()

# %% [markdown]
# ## 10. Profit Margin by Product

# %%
product = clean_df.groupby('Product Name')[['Sales','Profit']].sum()
product['Profit Margin'] = product['Profit'] / product['Sales']
product = product.sort_values('Profit Margin')
plt.figure(figsize=(10,6))
plt.bar(product.index, product['Profit Margin'])
plt.title('Profit Margin by Product')
plt.xlabel('Product')
plt.ylabel('Profit Margin')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ## 11. Problem Statement
#
# Strong sales do not always translate into equally strong profit. The analysis focuses on where profitability is weaker and what business actions can improve margin performance.

# %% [markdown]
# ## 12. Recommendations
#
# - Review pricing and cost structure for low-margin products.
# - Prioritize high-margin products in promotions.
# - Track margin monthly by product, category, and region.
# - Use profit margin as a decision metric, not sales alone.
